# %% [markdown]
# <a href="https://colab.research.google.com/github/kelseymour/NEA-Grant-Topic-Modeling/blob/main/NEA_code_scratchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NEA Grants Text Mining and Topic Modeling

# %% [markdown]
# Set Up

# %%
# !pip install pyldavis
# !pip install lbl2vec
# !pip install bertopic
# !pip install --upgrade pandas
# !python -m spacy download en_core_web_sm

# %%
import pandas as pd
pd.options.plotting.backend = "plotly"
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
import re
import string
from pprint import pprint
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.parsing.preprocessing import strip_tags
from gensim.models.doc2vec import TaggedDocument
import spacy
import pyLDAvis
import pyLDAvis.gensim_models
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
from transformers import pipeline
from bertopic import BERTopic
from sklearn.compose import make_column_transformer
from sklearn.feature_extraction.text import CountVectorizer
import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:58: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   distutils.version.LooseVersion(required_tensorflow_version)):

# %% [markdown]
# Cleaning Text Column

# %%
def remove_punctuations(text):
    for char in string.punctuation:
        text = text.replace(char, '')
    return text
def lemmatize_it(sent):
    empty = []
    for word, tag in pos_tag(word_tokenize(sent)):
        wntag = tag[0].lower()
        wntag = wntag if wntag in ['a', 'r', 'n', 'v'] else None
        if not wntag:
            lemma = word
            empty.append(lemma)
        else:
            lemma = lemmatizer.lemmatize(word, wntag)
            empty.append(lemma)
    return ' '.join(empty)

# %%
df = pd.read_excel("Orchestra_NEA_Grants.xlsx")
df = df.dropna(how="all")
df = df.reset_index()
df["Grant From Date"] = pd.to_datetime(df["Grant From Date"])
df["Grant To Date"] = pd.to_datetime(df["Grant To Date"])
df["grant_length"] = df["Grant To Date"] - df["Grant From Date"]
df["Fiscal Year"] = df["Fiscal Year"].astype(int)
df = df[df["Fiscal Year"] >= 2013]
cols = df.select_dtypes(['object']).columns
df[cols] = df[cols].apply(lambda x: x.str.strip())
df = df.replace('\n',' ', regex=True)
df = df.loc[:, ~df.columns.isin(["Popular Name", "Application Number",
                                 "Zip", "Congressional District",
                                 "Grant From Date", "Grant To Date"])]

df.tail()
# Out:
#       index                Organization Name  \
# 2291   2292  Youth Orchestras of San Antonio
# 2292   2293  Youth Orchestras of San Antonio
# 2293   2294  Youth Orchestras of San Antonio
# 2294   2295  Youth Orchestras of San Antonio
# 2295   2296  Youth Orchestras of San Antonio
#
#                                      Discipline / Field  \
# 2291  Coronavirus Aid, Relief, and Economic Security...
# 2292                                              Music
# 2293                                  Challenge America
# 2294                                  Challenge America
# 2295                                  Challenge America
#
#                                                Category         City State  \
# 2291  Coronavirus Aid, Relief, and Economic Security...  SAN ANTONIO    TX
# 2292                                          Art Works  SAN ANTONIO    TX
# 2293                                  Challenge America  SAN ANTONIO    TX
# 2294                                  Challenge America  SAN ANTONIO    TX
# 2295                                  Challenge America  SAN ANTONIO    TX
#
#                                     Project Description  Fiscal Year  \
# 2291  To support personnel costs in response to the ...         2020
# 2292  To support the annual YOSA Invitational music ...         2019
# 2293  To support Mozart at the Opera. Soprano Shana ...         2017
# 2294  To support the production of Carl Orff's "Carm...         2015
# 2295  To support the commission and premiere of a ne...         2013
#
#       Grant Amount grant_length
# 2291       50000.0      61 days
# 2292       10000.0     180 days
# 2293       10000.0      30 days
# 2294       10000.0     180 days
# 2295       10000.0     152 days

# %% [markdown]
# First look at some visualizations

# %%
df["Grant Amount"].hist(bins=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fef47b28-493c-4279-9f84-5d745c0586c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fef47b28-493c-4279-9f84-5d745c0586c8")) {                    Plotly.newPlot(                        "fef47b28-493c-4279-9f84-5d745c0586c8",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=Grant Amount\u003cbr\u003evalue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Grant Amount","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Grant Amount","offsetgroup":"Grant Amount","orientation":"v","showlegend":true,"x":[2650.0,15000.0,10000.0,20000.0,10000.0,25000.0,25000.0,25000.0,25000.0,50000.0,25000.0,15000.0,15000.0,15000.0,20000.0,20000.0,10000.0,10000.0,50000.0,10000.0,10000.0,10000.0,10000.0,20000.0,20000.0,20000.0,20000.0,25000.0,25000.0,25000.0,30000.0,25000.0,25000.0,85000.0,90000.0,50000.0,90000.0,90000.0,25000.0,50000.0,90000.0,90000.0,90000.0,90000.0,90000.0,97500.0,15000.0,100000.0,15000.0,15000.0,10000.0,15000.0,10000.0,10000.0,15000.0,50000.0,15000.0,20000.0,15000.0,15000.0,10000.0,10000.0,10000.0,15000.0,50000.0,15000.0,15000.0,15000.0,15000.0,15000.0,10000.0,30000.0,40000.0,35000.0,40000.0,35000.0,35000.0,35000.0,35000.0,25000.0,40000.0,12500.0,150000.0,12000.0,10000.0,50000.0,10000.0,12500.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,15000.0,10000.0,16000.0,20000.0,15000.0,15000.0,15000.0,15000.0,25000.0,30000.0,25000.0,20000.0,20000.0,25000.0,20000.0,25000.0,25000.0,30000.0,25000.0,10000.0,45000.0,40000.0,40000.0,75000.0,100000.0,10000.0,100000.0,10000.0,10000.0,10000.0,15000.0,15000.0,15000.0,15000.0,15000.0,20000.0,15000.0,15000.0,15000.0,12500.0,12500.0,13000.0,10000.0,50000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,100000.0,15000.0,10000.0,50000.0,10000.0,10000.0,10000.0,10000.0,20000.0,50000.0,20000.0,50000.0,15000.0,10000.0,35000.0,20000.0,25000.0,50000.0,15000.0,20000.0,20000.0,20000.0,50000.0,35000.0,50000.0,45000.0,50000.0,70000.0,50000.0,75000.0,50000.0,50000.0,75000.0,50000.0,50000.0,75000.0,75000.0,50000.0,75000.0,50000.0,90000.0,50000.0,75000.0,45000.0,65000.0,50000.0,45000.0,50000.0,45000.0,50000.0,45000.0,35000.0,30000.0,52000.0,30000.0,60000.0,15000.0,15000.0,25000.0,15000.0,20000.0,20000.0,15000.0,50000.0,10000.0,12500.0,15000.0,15000.0,15000.0,10000.0,15000.0,50000.0,15000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,50000.0,10000.0,15000.0,50000.0,12500.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,30000.0,35000.0,45000.0,40000.0,45000.0,40000.0,60000.0,45000.0,50000.0,50000.0,65000.0,75000.0,50000.0,50000.0,75000.0,50000.0,75000.0,70000.0,80000.0,50000.0,60000.0,75000.0,50000.0,60000.0,50000.0,80000.0,75000.0,20000.0,15000.0,15000.0,35000.0,40000.0,40000.0,40000.0,50000.0,40000.0,40000.0,40000.0,40000.0,40000.0,40000.0,10000.0,10000.0,10000.0,10000.0,10000.0,12500.0,10000.0,10000.0,15000.0,10000.0,10000.0,25000.0,150000.0,25000.0,20000.0,20000.0,20000.0,20000.0,25000.0,25000.0,10000.0,20000.0,20000.0,15000.0,20000.0,15000.0,10000.0,25000.0,10000.0,50000.0,50000.0,50000.0,45000.0,45000.0,50000.0,50000.0,18000.0,50000.0,50000.0,50000.0,75000.0,18000.0,10000.0,15000.0,50000.0,15000.0,10000.0,10000.0,10000.0,20000.0,20000.0,20000.0,15000.0,27000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,40000.0,10000.0,20000.0,40000.0,10000.0,15000.0,15000.0,15000.0,50000.0,15000.0,10000.0,15000.0,15000.0,10000.0,12500.0,10000.0,10000.0,10000.0,10000.0,15000.0,10000.0,20000.0,20000.0,20000.0,20000.0,20000.0,20000.0,20000.0,10000.0,10000.0,10000.0,10000.0,10000.0,50000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10 ...

# %% [markdown]
# Plots of the Categories already labeled by the NEA. These are either not descriptive enough, or relate to specific programs that can contain a broad range of topics.

# %%
fig = df["Discipline / Field"].value_counts().plot(kind="bar",
                                                   title="Grants Awarded by NEA Discipline/Field",
                                                   width=1000, height=700)
fig.write_html("count_of_grants_by_discipine.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d0de7969-d873-4b57-94d5-a7049c96133a" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0de7969-d873-4b57-94d5-a7049c96133a")) {                    Plotly.newPlot(                        "d0de7969-d873-4b57-94d5-a7049c96133a",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eDiscipline \u002f Field=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","x":["Music","Challenge America","Arts Education","Arts Engagement in American Communities","Coronavirus Aid, Relief, and Economic Security (CARES) Act","American Rescue Plan","Opera","Media Arts","Creativity Connects","Folk & Traditional Arts","Research","Federal Partnerships","Presenting & Multidisciplinary Works"],"xaxis":"x","y":[621,104,58,57,48,19,16,11,4,3,2,2,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpo ...

# %%
fig = df["Category"].value_counts().plot(kind="bar",
                                         title="Grants Awarded by NEA Category",
                                         width=1000, height=900)
fig.write_html("count_of_grants_by_category.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="595cc494-3b9c-4e10-9f83-9d20268d7fd8" class="plotly-graph-div" style="height:900px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("595cc494-3b9c-4e10-9f83-9d20268d7fd8")) {                    Plotly.newPlot(                        "595cc494-3b9c-4e10-9f83-9d20268d7fd8",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eCategory=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","x":["Art Works","Grants for Arts Projects","Challenge America","Challenge America: Arts Engagement in American Communities","Coronavirus Aid, Relief, and Economic Security (CARES) Act","American Rescue Plan (ARP) Grants to Organizations","Creativity Connects","National Arts and Humanities Youth Program Awards","Research Grants in the Arts","Art Works: Research"],"xaxis":"x","y":[486,225,104,57,48,19,4,2,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0, ...

# %%
fig = df.plot(kind="box",
              x=df["Discipline / Field"],
              y=df["Grant Amount"],
              title="Amount Awarded by NEA Discipline/Field",
              width=1100, height=900)
fig.write_html("distribution_of_money_by_discipine.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1c542bca-a68a-4c09-8a45-db85169916e4" class="plotly-graph-div" style="height:900px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c542bca-a68a-4c09-8a45-db85169916e4")) {                    Plotly.newPlot(                        "1c542bca-a68a-4c09-8a45-db85169916e4",                        [{"alignmentgroup":"True","hovertemplate":"Discipline \u002f Field=%{x}\u003cbr\u003eGrant Amount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Challenge America","Music","Music","Music","Challenge America","Music","Music","Music","Music","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Music","Music","Music","Music","Music","Music","Arts Education","Arts Education","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Arts Education","Arts Engagement in American Communities","Arts Engagement in American Communities","Arts Engagement in American Communities","Music","Media Arts","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","American Rescue Plan","Music","Music","Research","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Music","Music","Music","Music","Music","Music","Research","Music","Music","Music","Music","Music","Music","Music","Music","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Music","Music","Music","Music","Music","Challenge America","Music","Music","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","American Rescue Plan","Music","Challenge America","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Challenge America","Music","Challenge America","Challenge America","Challenge America","Music","Challenge America","Music","Music","Arts Engagement in American Communities","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Arts Engagement in American Communities","Music","Music","Arts Education","Music","Arts Education","Federal Partnerships","Arts Education","Opera","Arts Engagement in American Communities","Arts Engagement in American Communities","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Challenge America","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Challenge America","Challenge America","Challenge America","Challenge America","Challenge America","Challenge America","American Rescue Plan","Music","Challenge America","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Challenge America","Music","Music","Music","Music","American Rescue Plan","Music","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Music","Music","Opera","Opera","Music","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Music","Arts Education","Arts Education","Arts Education","Arts Education","Arts Education","Arts Education","Arts Education","Arts Education","Arts Education","Arts Education","Music","Music","Music","Music","Music","Music","Music","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Music","Music","Music","Music","Music","Challenge America","Music","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Music","Challenge America","Challenge America" ...

# %%
fig = df.plot(kind="box",
              x=df["Category"],
              y=df["Grant Amount"],
              title="Amount Awarded by NEA Category",
              width=1100, height=900)
fig.write_html("distribution_of_money_by_category.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1d121380-67f2-403f-8794-d9705046392b" class="plotly-graph-div" style="height:900px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d121380-67f2-403f-8794-d9705046392b")) {                    Plotly.newPlot(                        "1d121380-67f2-403f-8794-d9705046392b",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003eGrant Amount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Challenge America","Grants for Arts Projects","Art Works","Art Works","Challenge America","Grants for Arts Projects","Grants for Arts Projects","Grants for Arts Projects","Art Works","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Grants for Arts Projects","Grants for Arts Projects","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Art Works","Challenge America: Arts Engagement in American Communities","Challenge America: Arts Engagement in American Communities","Challenge America: Arts Engagement in American Communities","Grants for Arts Projects","Grants for Arts Projects","Grants for Arts Projects","Grants for Arts Projects","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Grants for Arts Projects","Grants for Arts Projects","American Rescue Plan (ARP) Grants to Organizations","Grants for Arts Projects","Art Works","Research Grants in the Arts","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works: Research","Art Works","Grants for Arts Projects","Grants for Arts Projects","Art Works","Grants for Arts Projects","Grants for Arts Projects","Grants for Arts Projects","Art Works","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Art Works","Art Works","Art Works","Art Works","Art Works","Challenge America","Grants for Arts Projects","Art Works","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Grants for Arts Projects","Grants for Arts Projects","Grants for Arts Projects","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Grants for Arts Projects","American Rescue Plan (ARP) Grants to Organizations","Grants for Arts Projects","Challenge America","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Challenge America","Art Works","Challenge America","Challenge America","Challenge America","Art Works","Challenge America","Grants for Arts Projects","Grants for Arts Projects","Challenge America: Arts Engagement in American Communities","Grants for Arts Projects","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Grants for Arts Projects","Grants for Arts Projects","Grants for Arts Projects","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Challenge America: Arts Engagement in American Communities","Grants for Arts Projects","Grants for Arts Projects","Art Works","Art Works","Art Works","National Arts and Humanities Youth Program Awards","Art Works","Grants for Arts Projects","Challenge America: Arts Engagement in American Communities","Challenge America: Arts Engagement in American Communities","Grants for Arts Projects","Grants for Arts Projects","Grants for Arts Projects","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Art Works","Grants for Arts Projects","Challenge America","Coronavirus Aid, Relief, and Economic Security (CARES) Act","Challenge America","Challenge America","Challen ...

# %% [markdown]
# LDA: First attempt to get better labels based on project descriptions

# %%
data = df["Project Description"].values.tolist()
data = [re.sub('\S*@\S*\s?', '', sent) for sent in data]
data = [re.sub('\s+', ' ', sent) for sent in data]
data = [re.sub("\'", "", sent) for sent in data]
#print(data[0])

# %%
stop = stopwords.words('english')
extend = ['symphony', 'orchestra', 'philharmonic', 'philharmonia', 'de', 'el', 'annenberg', 'new', 'york',
          'paso', 'orleans', 'chicago', 'tanglewood', 'sarasota', 'berekely', 'cooper', 'st', 'luke',
          'kalamazoo', 'albuquerque', 'alabama', 'alaska', 'arizona', 'arkansas', 'california', 'colorado', 'connecticut',
          'delaware', 'florida', 'georgia', 'hawaii', 'idaho', 'illinois', 'indiana', 'iowa', 'kansas', 'kentucky', 'louisiana',
          'maine', 'maryland', 'massachusetts', 'michigan', 'minnesota', 'mississippi', 'missouri', 'montana', 'nebraska',
          'nevada', 'hampshire', 'jersey', 'mexico', 'north', 'carolina', 'dakota', 'ohio', 'oklahoma',
          'oregon', 'pennsylvania', 'rhode', 'island', 'south', 'tennessee', 'texas',
          'utah', 'vermont', 'virginia', 'washington', 'west', 'wisconsin', 'wyoming', 'with', 'berkeley', 'plymouth',
          'tuscon', 'mcgegan', 'long', 'beach', 'van', 'wilkinsburg', 'bend', 'fort', 'grant', 'people', 'anchorage',
          'concert', 'performance', 'purpose', 'support', 'project', 'columbus', 'john', '20042005', 'city', 'seattle',
          'san', 'francisco', 'los', 'angeles', 'charlotte', 'sonia', 'marie', 'ace', 'park', 'musician', 'ludwig', 'jr', 'philadelphia',
          'lido', 'hampton', 'indianapolis', 'tucson', 'minneapolis', 'nicollet', 'elliot']
stop_extended = stop + extend

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))#deacc=True removes punctuations
data_words = list(sent_to_words(data))
#print(data_words[:1])

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
#print(trigram_mod[bigram_mod[data_words[0]]])

# %%
# Define function for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_extended] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)
# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# Form Bigrams
#data_words_bigrams = make_bigrams(data_lemmatized)

print(data_lemmatized[:1])
# Out:
# [['purpose', 'support', 'series', 'community', 'outreach', 'concert', 'additional', 'project', 'description', 'provide', 'concert', 'community', 'venue', 'such', 'senior', 'care', 'health', 'care', 'facility', 'programming', 'present', 'partnership', 'community', 'organization', 'such', 'development', 'center', 'intend', 'beneficiary', 'resident', 'aiken', 'access', 'performance', 'include', 'individual', 'disability', 'intend', 'outcome', 'beneficiary', 'engage', 'art']]

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)
# Create Corpus
texts = data_lemmatized
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
#print(corpus[:1])

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=7,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the keyword of topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.026*"age" + 0.021*"low" + 0.019*"quartet" + 0.016*"income" + '
#   '0.016*"feature" + 0.014*"performance" + 0.014*"live" + 0.013*"concert" + '
#   '0.011*"competition" + 0.010*"soloist"'),
#  (1,
#   '0.063*"school" + 0.059*"music" + 0.058*"student" + 0.046*"program" + '
#   '0.021*"support" + 0.017*"youth" + 0.017*"provide" + 0.014*"high" + '
#   '0.013*"musician" + 0.013*"string"'),
#  (2,
#   '0.052*"work" + 0.041*"composer" + 0.032*"support" + 0.028*"project" + '
#   '0.027*"new" + 0.025*"music" + 0.021*"include" + 0.019*"performance" + '
#   '0.017*"festival" + 0.017*"feature"'),
#  (3,
#   '0.109*"covid" + 0.108*"pandemic" + 0.105*"cost" + 0.088*"support" + '
#   '0.085*"response" + 0.061*"personnel" + 0.043*"general" + 0.032*"operating" '
#   '+ 0.006*"model" + 0.005*"collect"'),
#  (4,
#   '0.029*"orchestra" + 0.021*"location" + 0.019*"more" + 0.018*"development" + '
#   '0.017*"train" + 0.015*"professional" + 0.014*"therapy" + 0.013*"expand" + '
#   '0.012*"therapist" + 0.009*"enable"'),
#  (5,
#   '0.052*"concert" + 0.042*"performance" + 0.037*"project" + 0.032*"community" '
#   '+ 0.031*"support" + 0.025*"orchestra" + 0.024*"activity" + 0.022*"include" '
#   '+ 0.019*"beneficiary" + 0.019*"intend"'),
#  (6,
#   '0.081*"ensemble" + 0.038*"master" + 0.037*"student" + 0.033*"class" + '
#   '0.028*"chamber" + 0.021*"middle" + 0.016*"present" + 0.015*"band" + '
#   '0.014*"small" + 0.013*"performance"')]

# %%
# Compute Perplexity (a measure of how good the model is; lower the better)
print('\nPerplexity: ', lda_model.log_perplexity(corpus))

# Compute Coherence Score (measure of human readability, higher better)
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -6.345036048343259
#
# Coherence Score:  0.4525256643668202

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 5     -0.239188  0.061877       1        1  36.837038
# 2     -0.185105  0.177981       2        1  24.304312
# 1     -0.154954 -0.200433       3        1  20.727242
# 0      0.164482  0.117715       4        1   6.543151
# 6      0.058668 -0.199821       5        1   5.456667
# 4      0.158897 -0.016490       6        1   4.112223
# 3      0.197200  0.059172       7        1   2.019368, topic_info=             Term        Freq       Total Category  logprob  loglift
# 32        support  943.000000  943.000000  Default   30.000  30.0000
# 64        student  500.000000  500.000000  Default   29.000  29.0000
# 62         school  551.000000  551.000000  Default   28.000  28.0000
# 67           work  451.000000  451.000000  Default   27.000  27.0000
# 45       composer  358.000000  358.000000  Default   26.000  26.0000
# ..            ...         ...         ...      ...      ...      ...
# 414     continued    0.206254    1.012320   Topic7   -8.165   2.3115
# 421   expenditure    0.206254    1.012320   Topic7   -8.165   2.3115
# 424  longitudinal    0.206254    1.012320   Topic7   -8.165   2.3115
# 426         point    0.206254    1.012320   Topic7   -8.165   2.3115
# 32        support   64.157440  943.466307   Topic7   -2.425   1.2142
#
# [376 rows x 6 columns], token_table=      Topic      Freq      Term
# term
# 0         1  0.982715    access
# 0         3  0.012439    access
# 246       3  0.975691   acquire
# 34        1  0.730968  activity
# 34        2  0.267483  activity
# ...     ...       ...       ...
# 3031      5  0.692059      yosa
# 232       2  0.424727     young
# 232       3  0.566303     young
# 288       3  0.918875     youth
# 288       5  0.080219     youth
#
# [440 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[6, 3, 2, 1, 7, 5, 4])

# %%
pyLDAvis.save_html(vis, 'lda_7_topics.html')

# %%
 all_topics = lda_model.get_document_topics(corpus, minimum_probability=0.0)
 all_topics_csr = gensim.matutils.corpus2csc(all_topics)
 all_topics_numpy = all_topics_csr.T.toarray()
 all_topics_df = pd.DataFrame(all_topics_numpy)

# %%
all_topics_df.iloc[:3]
# Out:
#           0         1         2         3         4         5         6
# 0  0.004777  0.052708  0.061840  0.001876  0.001832  0.872656  0.004310
# 1  0.003897  0.111160  0.545329  0.020507  0.001413  0.261568  0.056126
# 2  0.006022  0.111800  0.084860  0.002361  0.059179  0.730367  0.005412

# %%
print(len(df))
print(len(all_topics_df))
# Out:
# 947
# 947

# %%
df_lda = pd.merge(df, all_topics_df, left_index=True, right_index=True)

# %%
#df_lda = pd.concat([df, all_topics_df], axis=1)
df_lda = df_lda.rename(columns={0: 'lda_7', 1: 'lda_1', 2: 'lda_2', 3: 'lda_3', 4: 'lda_4', 5: 'lda_5', 6: 'lda_6'})
df_lda['LDA_label_7_topics'] = df_lda[["lda_7", "lda_1", "lda_2", "lda_3", "lda_4", "lda_5", "lda_6"]].idxmax(axis=1)
df_lda.tail()
# Out:
#      Unnamed: 0  index                          Organization Name  \
# 398         933    934          Grant Park Orchestral Association
# 399         934    935          Grant Park Orchestral Association
# 400         935    936          Grant Park Orchestral Association
# 401         936    937          Grant Park Orchestral Association
# 402         946    947  Greater Connecticut Youth Orchestras Inc.
#
#     Discipline / Field           Category       City State  \
# 398              Music          Art Works    CHICAGO    IL
# 399              Music          Art Works    CHICAGO    IL
# 400              Music          Art Works    CHICAGO    IL
# 401              Music          Art Works    CHICAGO    IL
# 402  Challenge America  Challenge America  FAIRFIELD    CT
#
#                                    Project Description  Fiscal Year  \
# 398  To support the Grant Park Music Festival. The ...         2017
# 399  To support the Grant Park Music Festival. The ...         2016
# 400  To support the Grant Park Music Festival. The ...         2015
# 401  To support the Grant Park Music Festival. The ...         2014
# 402  Purpose: To support youth orchestra activities...         2023
#
#      Grant Amount  ...     lda_7     lda_1     lda_2     lda_3     lda_4  \
# 398       30000.0  ...  0.336753  0.413541  0.048189  0.005202  0.005081
# 399       34000.0  ...  0.004797  0.430956  0.195608  0.001874  0.001831
# 400       30000.0  ...  0.005696  0.563277  0.100505  0.002231  0.002179
# 401       30000.0  ...  0.006594  0.137145  0.503053  0.034942  0.002446
# 402       10000.0  ...  0.073683  0.345543  0.199139  0.001793  0.001751
#
#         lda_5     lda_6                                         lemma_list  \
# 398  0.179267  0.011967  ['support', 'young', 'musician', 'program', 'c...
# 399  0.278761  0.086172  ['support', 'performance', 'music', 'education...
# 400  0.237702  0.088409  ['support', 'annual', 'foosa', 'summer', 'fest...
# 401  0.310075  0.005746  ['support', 'commissioning', 'come', 'home', '...
# 402  0.060114  0.317977  ['support', 'commission', 'premiere', 'new', '...
#
#                                         processed_text LDA_label_7_topics
# 398  music festival free summer festival take place...              lda_1
# 399  music festival free summer festival take place...              lda_1
# 400  music festival free summer festival take place...              lda_1
# 401  music festival free summer festival take place...              lda_2
# 402  youth activity underserved student additional ...              lda_1
#
# [5 rows x 21 columns]

# %%
#df_lda['LDA_label'] = df_lda[[1, 2, 3, 4, 5, 6, 7]].idxmax(axis=1)

# %%
df_lda["lemma_list"] = pd.Series(data_lemmatized)
#df_lda.head()

# %%
df_lda.to_csv("df_lda.csv")

# %%
df_lda = pd.read_csv("df_lda.csv")

# %%
keyword_list = ["concert series", "composer residency", "composer commission",
                "festival", "conference", "operational cost", "competition",
                "job development", "covid relief", "opera", "cultural diversity",
                "community outreach", "student education", "masterclass teaching",
                "chamber music", "tour", "recording", "jazz"]

# %% [markdown]
# BART: Second attempt to get better labels with one-shot classification

# %%
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")

# %%
sequence_to_classify = "Purpose: To support a composer residency by Brian Nabors including commissions, performances, and educational activities. Additional Project Description: Plans include the completion of two works for orchestra and performances of these and other works by the composer. Nabors will lead master classes in local schools and colleges. Intended Beneficiaries: Programs will benefit the composer-in-residence as well as general audiences in Birmingham, Alabama, and area public school students. Intended Outcome: Artistic activities and traditions are supported to strengthen the nation's cultural infrastructure."
candidate_labels = keyword_list
result = classifier(sequence_to_classify, candidate_labels)

# %%
#sanity check
print(result['labels'])
print(result['labels'][0])
print(result['labels'][1])
print(result['labels'][2])
print(result['scores'])
print(result['scores'][0])
print(result['scores'][1])
print(result['scores'][2])
# Out:
# ['composer residency', 'student education', 'masterclass teaching', 'composer commission', 'community outreach', 'concert series', 'cultural diversity', 'tour', 'recording', 'covid relief', 'operational cost', 'conference', 'festival', 'chamber music', 'job development', 'competition', 'jazz', 'opera']
# composer residency
# student education
# masterclass teaching
# [0.5183343887329102, 0.1170012578368187, 0.1134801134467125, 0.0954497903585434, 0.0757998526096344, 0.01959664560854435, 0.01060319971293211, 0.01045725867152214, 0.009680742397904396, 0.008682592771947384, 0.00487194349989295, 0.0037699646782130003, 0.003521531354635954, 0.0020360550843179226, 0.0018643977819010615, 0.0018038754351437092, 0.0015917744021862745, 0.0014546791790053248]
# 0.5183343887329102
# 0.1170012578368187
# 0.1134801134467125

# %%
def get_bart_labels(text_sample):
  candidate_labels = ["concert series", "composer residency", "composer commission",
                "festival", "conference", "operational cost", "competition",
                "job development", "covid relief", "opera", "cultural diversity",
                "community outreach", "student education", "masterclass teaching",
                "chamber music", "tour", "recording", "jazz"]
  sequence_to_classify = text_sample
  result = classifier(sequence_to_classify, candidate_labels)
  return result['labels'][0], result['labels'][1], result['labels'][2], result['scores'][0], result['scores'][1], result['scores'][2]

# %%
#Label extraction is not fully repoduced in this notebook because
#running this classification takes SO long - saved csv from previous time
#df_lda[["bart_label_1", "bart_label_2", "bart_label_3", "bart_score_1", "bart_score_2", "bart_score_3"]] = df_lda.apply(lambda x: get_bart_labels(x["Project Description"]), axis=1)

# %%
#df_all = pd.concat([df_lda, pd.DataFrame(df["Project Description"])], axis=1)

# %%
#df_lda["Project Description"].tail(20)

# %%
lemmatizer = WordNetLemmatizer()
df_lda["processed_text"] = df_lda["Project Description"].str.replace('\n',' ').str.lower()
df_lda['processed_text'] = df_lda['processed_text'].apply(lemmatize_it)
df_lda["processed_text"] = df_lda['processed_text'].apply(remove_punctuations)
df_lda['processed_text'] = df_lda['processed_text'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_extended]))

# %%
df_lda['processed_text'][1]
# Out:
# 'composer residency brian nabors include commission educational activity additional description plan include completion two work work composer nabors lead master class local school college intend beneficiary program benefit composerinresidence well general audience birmingham area public school student intend outcome artistic activity tradition strengthen nation cultural infrastructure'

# %% [markdown]
# BERT Topic Modeling: Third attempt to get better labels

# %%
docs_processed = df_lda["processed_text"]

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs_processed)
topic_model.get_topic_info()
# Out:
#    Topic  Count                                   Name  \
# 0      0    366        0_music_include_student_program
# 1      1     21  1_personnel_response_pandemic_covid19
# 2      2     16  2_operating_general_response_pandemic
#
#                                       Representation  \
# 0  [music, include, student, program, activity, s...
# 1  [personnel, response, pandemic, covid19, cost,...
# 2  [operating, general, response, pandemic, covid...
#
#                                  Representative_Docs
# 0  [festival contemporary music music center addi...
# 1  [personnel cost response covid19 pandemic, per...
# 2  [general operating cost response covid19 pande...

# %%
topic_model.get_document_info(docs_processed)
# Out:
#                                               Document  Topic  \
# 0    series community outreach additional descripti...      0
# 1    composer residency brian nabors include commis...      0
# 2    outreach activity plan include instrument pet ...      0
# 3    sound investment residency commissioning plan ...      0
# 4    outreach activity feature flutist joseph firec...      0
# ..                                                 ...    ...
# 398  music festival free summer festival take place...      0
# 399  music festival free summer festival take place...      0
# 400  music festival free summer festival take place...      0
# 401  music festival free summer festival take place...      0
# 402  youth activity underserved student additional ...      0
#
#                                 Name  \
# 0    0_music_include_student_program
# 1    0_music_include_student_program
# 2    0_music_include_student_program
# 3    0_music_include_student_program
# 4    0_music_include_student_program
# ..                               ...
# 398  0_music_include_student_program
# 399  0_music_include_student_program
# 400  0_music_include_student_program
# 401  0_music_include_student_program
# 402  0_music_include_student_program
#
#                                         Representation  \
# 0    [music, include, student, program, activity, s...
# 1    [music, include, student, program, activity, s...
# 2    [music, include, student, program, activity, s...
# 3    [music, include, student, program, activity, s...
# 4    [music, include, student, program, activity, s...
# ..                                                 ...
# 398  [music, include, student, program, activity, s...
# 399  [music, include, student, program, activity, s...
# 400  [music, include, student, program, activity, s...
# 401  [music, include, student, program, activity, s...
# 402  [music, include, student, program, activity, s...
#
#                                    Representative_Docs  \
# 0    [festival contemporary music music center addi...
# 1    [festival contemporary music music center addi...
# 2    [festival contemporary music music center addi...
# 3    [festival contemporary music music center addi...
# 4    [festival contemporary music music center addi...
# ..                                                 ...
# 398  [festival contemporary music music center addi...
# 399  [festival contemporary music music center addi...
# 400  [festival contemporary music music center addi...
# 401  [festival contemporary music music center addi...
# 402  [festival contemporary music music center addi...
#
#                                            Top_n_words  Probability  \
# 0    music - include - student - program - activity...          1.0
# 1    music - include - student - program - activity...          1.0
# 2    music - include - student - program - activity...          1.0
# 3    music - include - student - program - activity...          1.0
# 4    music - include - student - program - activity...          1.0
# ..                                                 ...          ...
# 398  music - include - student - program - activity...          1.0
# 399  music - include - student - program - activity...          1.0
# 400  music - include - student - program - activity...          1.0
# 401  music - include - student - program - activity...          1.0
# 402  music - include - student - program - activity...          1.0
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ..                       ...
# 398                    False
# 399                    False
# 400                    False
# 401                    False
# 402                    False
#
# [403 rows x 8 columns]

# %%
bertopic_df_processed = pd.DataFrame(topic_model.get_document_info(docs_processed))
data_topics_processed = df_lda.merge(bertopic_df_processed, left_on="processed_text", right_on="Document")
data_topics_processed.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  index                      Organization Name  \
# 0             0           0      1  Aiken Symphony Orchestra Incorporated
# 1             1           1      2    Alabama Symphonic Association, Inc.
# 2             2           2      3    Alabama Symphonic Association, Inc.
# 3             3           3      4    Alabama Symphonic Association, Inc.
# 4             4          14     15      Albany Symphony Association, Inc.
#
#   Discipline / Field                  Category        City State  \
# 0  Challenge America         Challenge America       Aiken    SC
# 1              Music  Grants for Arts Projects  BIRMINGHAM    AL
# 2              Music                 Art Works  BIRMINGHAM    AL
# 3              Music                 Art Works  BIRMINGHAM    AL
# 4  Challenge America         Challenge America      ALBANY    GA
#
#                                  Project Description  Fiscal Year  ...  \
# 0  Purpose: To support a series of community outr...         2022  ...
# 1  Purpose: To support a composer residency by Br...         2022  ...
# 2  To support concerts and outreach activities by...         2015  ...
# 3  To support Sound Investment, a residency and c...         2013  ...
# 4  To support a performance and outreach activiti...         2016  ...
#
#                                       processed_text LDA_label_7_topics  \
# 0  series community outreach additional descripti...              lda_5
# 1  composer residency brian nabors include commis...              lda_2
# 2  outreach activity plan include instrument pet ...              lda_5
# 3  sound investment residency commissioning plan ...              lda_1
# 4  outreach activity feature flutist joseph firec...              lda_2
#
#                                             Document  Topic  \
# 0  series community outreach additional descripti...      0
# 1  composer residency brian nabors include commis...      0
# 2  outreach activity plan include instrument pet ...      0
# 3  sound investment residency commissioning plan ...      0
# 4  outreach activity feature flutist joseph firec...      0
#
#                               Name  \
# 0  0_music_include_student_program
# 1  0_music_include_student_program
# 2  0_music_include_student_program
# 3  0_music_include_student_program
# 4  0_music_include_student_program
#
#                                       Representation  \
# 0  [music, include, student, program, activity, s...
# 1  [music, include, student, program, activity, s...
# 2  [music, include, student, program, activity, s...
# 3  [music, include, student, program, activity, s...
# 4  [music, include, student, program, activity, s...
#
#                                  Representative_Docs  \
# 0  [festival contemporary music music center addi...
# 1  [festival contemporary music music center addi...
# 2  [festival contemporary music music center addi...
# 3  [festival contemporary music music center addi...
# 4  [festival contemporary music music center addi...
#
#                                          Top_n_words  Probability  \
# 0  music - include - student - program - activity...          1.0
# 1  music - include - student - program - activity...          1.0
# 2  music - include - student - program - activity...          1.0
# 3  music - include - student - program - activity...          1.0
# 4  music - include - student - program - activity...          1.0
#
#   Representative_document
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
#
# [5 rows x 30 columns]

# %%
#data_topics_processed = df.merge(bertopic_df_processed, left_on="processed_text", right_on="Document")

# %% [markdown]
# Bucket grants into categories based in funding amount

# %%
interval_range = pd.interval_range(start=0, freq=10000, end=160000)
data_topics_processed['10k_bin'] = pd.cut(data_topics_processed['Grant Amount'], bins=interval_range)
data_topics_processed['decile'] = pd.cut(data_topics_processed['Grant Amount'], bins=10)

# %%
data_topics_processed.to_csv("full_data.csv")

# %%
df_full = pd.read_csv("df_clean_10_yrs.csv")

# %% [markdown]
# Visualizations based on new - better - labels

# %%
fig = df_full["LDA_label_6_topics"].value_counts().plot(kind="bar",
                                                   title="Grants Awarded by LDA Topic",
                                                   width=1000, height=700)
fig.write_html("count_of_grants_by_lda_topic.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="020edda5-4a14-4c4d-9769-721147865530" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("020edda5-4a14-4c4d-9769-721147865530")) {                    Plotly.newPlot(                        "020edda5-4a14-4c4d-9769-721147865530",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eLDA_label_6_topics=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","x":["lda_topic_5","lda_topic_2","lda_topic_1","lda_topic_3","lda_topic_6","lda_topic_4"],"xaxis":"x","y":[396,190,188,90,57,26],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"so ...

# %%
fig = df_full["bart_label_1"].value_counts().plot(kind="bar",
                                                   title="Grants Awarded by LLM First Topic",
                                                   width=1000, height=700)
fig.write_html("count_of_grants_by_llm_topic_1.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fe15f9bb-abb7-421b-aec6-93dc3d32e823" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe15f9bb-abb7-421b-aec6-93dc3d32e823")) {                    Plotly.newPlot(                        "fe15f9bb-abb7-421b-aec6-93dc3d32e823",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003ebart_label_1=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","x":["community outreach","concert series","student education","covid relief","composer commission","chamber music","festival","cultural diversity","operations jobs","opera","competition"],"xaxis":"x","y":[141,91,42,40,28,27,18,7,3,3,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2 ...

# %%
fig = df_full["bart_label_2"].value_counts().plot(kind="bar",
                                                   title="Grants Awarded by LLM Second Topic",
                                                   width=1000, height=700)
fig.write_html("count_of_grants_by_llm_topic_2.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8530b6d6-efaa-4cb2-b16e-de6ce8a58f61" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8530b6d6-efaa-4cb2-b16e-de6ce8a58f61")) {                    Plotly.newPlot(                        "8530b6d6-efaa-4cb2-b16e-de6ce8a58f61",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003ebart_label_2=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","x":["community outreach","concert series","student education","composer commission","cultural diversity","operations jobs","chamber music","covid relief","festival","competition","recording tour","opera","masterclass"],"xaxis":"x","y":[120,111,40,32,29,21,14,13,12,4,3,3,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"co ...

# %%
fig = df_full["LDA_label_6_topics"].plot(kind="box",
              x=df_full["LDA_label_6_topics"],
              y=df_full["Grant Amount"],
              title="Amount Awarded by LDA Topic",
              width=1100, height=900)
# fig = df.plot.box(y=df["Grant Amount"],
#               x=df["LDA_topic"])
              #title="Amount Awarded by LDA Topic",
              #width=11000, height=900)
fig.write_html("distribution_of_money_by_lda_topic.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="456cd7f9-8a1a-40fa-be4c-f21823ac8ec7" class="plotly-graph-div" style="height:900px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("456cd7f9-8a1a-40fa-be4c-f21823ac8ec7")) {                    Plotly.newPlot(                        "456cd7f9-8a1a-40fa-be4c-f21823ac8ec7",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["lda_topic_5","lda_topic_2","lda_topic_5","lda_topic_1","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_3","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_5","lda_topic_1","lda_topic_1","lda_topic_3","lda_topic_1","lda_topic_1","lda_topic_5","lda_topic_5","lda_topic_2","lda_topic_5","lda_topic_2","lda_topic_3","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_4","lda_topic_4","lda_topic_2","lda_topic_4","lda_topic_4","lda_topic_4","lda_topic_3","lda_topic_4","lda_topic_4","lda_topic_4","lda_topic_4","lda_topic_4","lda_topic_4","lda_topic_4","lda_topic_4","lda_topic_5","lda_topic_5","lda_topic_2","lda_topic_5","lda_topic_5","lda_topic_6","lda_topic_6","lda_topic_3","lda_topic_6","lda_topic_6","lda_topic_6","lda_topic_6","lda_topic_6","lda_topic_5","lda_topic_3","lda_topic_3","lda_topic_3","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_5","lda_topic_5","lda_topic_3","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_6","lda_topic_5","lda_topic_5","lda_topic_2","lda_topic_6","lda_topic_5","lda_topic_3","lda_topic_5","lda_topic_2","lda_topic_6","lda_topic_6","lda_topic_6","lda_topic_2","lda_topic_6","lda_topic_5","lda_topic_4","lda_topic_5","lda_topic_4","lda_topic_4","lda_topic_4","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_4","lda_topic_4","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_3","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_1","lda_topic_2","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_1","lda_topic_1","lda_topic_5","lda_topic_5","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_2","lda_topic_5","lda_topic_3","lda_topic_5","lda_topic_2","lda_topic_6","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_2","lda_topic_3","lda_topic_5","lda_topic_3","lda_topic_5","lda_topic_5","lda_topic_6","lda_topic_2","lda_topic_5","lda_topic_2","lda_topic_3","lda_topic_3","lda_topic_2","lda_topic_6","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_3","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_2","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_2","lda_topic_5","lda_topic_3","lda_topic_5","lda_topic_5","lda_topic_2","lda_topic_6","lda_topic_5","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_5","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_5","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_1","lda_topic_2","lda_topic_2","lda_topic_2","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_3","lda_topic_2","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_5","lda_topic_2","lda_topic_2","lda_topic_3","lda_topic_1","lda_topic_1","lda_topic_6","lda_topic_4","lda_topic_1","lda_topic_2","lda_topic_5","lda_topic_5","lda_topic_3","lda_topic_5","lda_topic_5","lda_topic_3"," ...

# %%
fig = df_full.plot(kind="box",
              x=df_full["bart_label_1"],
              y=df_full["Grant Amount"],
              title="Amount Awarded by LLM First Topic",
              width=1100, height=900)
fig.write_html("distribution_of_money_by_llm_topic_1.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9654e32d-2bd1-41ca-913c-e865277cdec1" class="plotly-graph-div" style="height:900px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9654e32d-2bd1-41ca-913c-e865277cdec1")) {                    Plotly.newPlot(                        "9654e32d-2bd1-41ca-913c-e865277cdec1",                        [{"alignmentgroup":"True","hovertemplate":"bart_label_1=%{x}\u003cbr\u003eGrant Amount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["community outreach","student education","community outreach","composer commission","composer commission","student education","community outreach","community outreach","composer commission","community outreach","community outreach","covid relief","composer commission","concert series","concert series","concert series","chamber music","concert series","concert series","chamber music","chamber music","chamber music","chamber music","covid relief","covid relief","community outreach","concert series","concert series","concert series","concert series","concert series","concert series","concert series","community outreach","community outreach","covid relief","community outreach","community outreach","cultural diversity","community outreach","community outreach","community outreach","community outreach","student education","student education","student education","covid relief","student education","concert series","community outreach","covid relief","community outreach","concert series","community outreach","operations jobs","covid relief","covid relief","student education","composer commission","community outreach","concert series","opera","covid relief","covid relief","composer commission","composer commission","concert series","festival","concert series","festival","chamber music","chamber music","concert series","concert series","chamber music","concert series","chamber music","opera","concert series","concert series","chamber music","composer commission","composer commission","concert series","community outreach","community outreach","community outreach","community outreach","covid relief","concert series","community outreach","festival","community outreach","student education","community outreach","concert series","concert series","community outreach","chamber music","cultural diversity","cultural diversity","covid relief","concert series","student education","community outreach","community outreach","community outreach","concert series","concert series","community outreach","concert series","community outreach","concert series","covid relief","concert series","concert series","community outreach","community outreach","community outreach","community outreach","festival","covid relief","concert series","concert series","concert series","community outreach","composer commission","composer commission","concert series","student education","student education","student education","community outreach","concert series","composer commission","composer commission","student education","student education","covid relief","student education","student education","student education","cultural diversity","concert series","community outreach","concert series","festival","concert series","community outreach","covid relief","student education","covid relief","community outreach","community outreach","community outreach","festival","covid relief","covid relief","student education","student education","covid relief","community outreach","community outreach","community outreach","student education","community outreach","community outreach","covid relief","festival","festival","festival","festival","festival","festival","concert series","c ...

# %%
fig = df_full.plot(kind="box",
              x=df_full["bart_label_2"],
              y=df_full["Grant Amount"],
              title="Amount Awarded by LLM Second Topic",
              width=1100, height=900)
fig.write_html("distribution_of_money_by_llm_topic_2.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="040ce1be-cd07-4c2e-8d9b-858b623cc965" class="plotly-graph-div" style="height:900px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("040ce1be-cd07-4c2e-8d9b-858b623cc965")) {                    Plotly.newPlot(                        "040ce1be-cd07-4c2e-8d9b-858b623cc965",                        [{"alignmentgroup":"True","hovertemplate":"bart_label_2=%{x}\u003cbr\u003eGrant Amount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["concert series","composer commission","concert series","community outreach","festival","community outreach","concert series","cultural diversity","concert series","recording tour","concert series","operations jobs","concert series","composer commission","composer commission","cultural diversity","concert series","chamber music","cultural diversity","student education","student education","concert series","concert series","operations jobs","composer commission","concert series","student education","community outreach","community outreach","community outreach","student education","recording tour","community outreach","student education","masterclass","community outreach","covid relief","covid relief","covid relief","composer commission","composer commission","covid relief","covid relief","concert series","cultural diversity","concert series","operations jobs","concert series","community outreach","concert series","composer commission","concert series","cultural diversity","concert series","covid relief","operations jobs","composer commission","community outreach","community outreach","opera","student education","community outreach","composer commission","composer commission","covid relief","operations jobs","community outreach","concert series","community outreach","chamber music","concert series","festival","composer commission","composer commission","festival","community outreach","festival","community outreach","composer commission","community outreach","festival","community outreach","concert series","community outreach","concert series","cultural diversity","concert series","concert series","composer commission","cultural diversity","concert series","concert series","student education","community outreach","concert series","community outreach","community outreach","student education","concert series","opera","concert series","composer commission","cultural diversity","chamber music","student education","student education","student education","community outreach","community outreach","concert series","community outreach","concert series","chamber music","composer commission","community outreach","composer commission","concert series","concert series","concert series","concert series","community outreach","composer commission","community outreach","community outreach","community outreach","composer commission","community outreach","festival","festival","community outreach","community outreach","community outreach","student education","community outreach","community outreach","student education","concert series","chamber music","operations jobs","community outreach","community outreach","community outreach","student education","festival","student education","community outreach","concert series","community outreach","concert series","operations jobs","recording tour","composer commission","concert series","concert series","competition","concert series","operations jobs","operations jobs","community outreach","concert series","operations jobs","concert series","concert series","concert series","community outreach","student education","concert series","composer commission","community outreach","community outreach"," ...

# %% [markdown]
# Top words found in each funding amount bucket

# %%
df_full_clean = df_full[df_full['bart_label_1'].notna()]

# %%
vectorizer = CountVectorizer()
transformer = make_column_transformer((vectorizer, 'bart_label_1'), (vectorizer, 'bart_label_2'))
features = transformer.fit_transform(df_full_clean[["bart_label_1", "bart_label_2"]])

# %%
topwords = pd.DataFrame(features.toarray(), index=pd.MultiIndex.from_frame(pd.DataFrame(df_full_clean['10k_bin'])))
topwords.columns = transformer.get_feature_names_out()
topwords = topwords.reset_index().melt(id_vars=['10k_bin'],
                                                 var_name='WORDS',
                                                 value_name='Value')
topwords = topwords.groupby(['10k_bin', 'WORDS'])['Value'].sum().reset_index()
topwords = topwords.groupby(['10k_bin']).apply(lambda x: x.nlargest(20, 'Value'))
topwords.reset_index(drop=True, inplace=True)

# %%
topwords
# Out:
#              10k_bin                         WORDS  Value
# 0         (0, 10000]  countvectorizer-1__community     42
# 1         (0, 10000]   countvectorizer-1__outreach     42
# 2         (0, 10000]    countvectorizer-2__concert     34
# 3         (0, 10000]     countvectorizer-2__series     34
# 4         (0, 10000]  countvectorizer-2__community     31
# ..               ...                           ...    ...
# 215  (90000, 100000]    countvectorizer-1__concert      0
# 216  (90000, 100000]      countvectorizer-1__covid      0
# 217  (90000, 100000]   countvectorizer-1__cultural      0
# 218  (90000, 100000]  countvectorizer-1__diversity      0
# 219  (90000, 100000]       countvectorizer-1__jobs      0
#
# [220 rows x 3 columns]
